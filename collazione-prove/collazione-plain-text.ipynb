# %% [markdown]
# Questa è un esempio di collazione, utilizzando [CollateX](http://collatex.net/).
#
# Mostra i possibili risultati (e serve a decidere come tarare il programma per questi testi) e aiuta a correggere la trascrizione

# %%
from collatex import *
collation = Collation()
witness_16998 = open( "paragrafo-1-16998.txt", encoding='utf-8' ).read()
witness_354 = open( "paragrafo-1-354.txt", encoding='utf-8' ).read()
collation.add_plain_witness( "BnF 16998", witness_16998 )
collation.add_plain_witness( "BnF 354", witness_354 )
alignment_table = collate(collation, layout='vertical', output='html2')
# Out:
# <TABLE border="1" cellpadding="4" style="border: 1px solid #000000; border-collapse: collapse;">
#  <TR>
#   <TH>BnF 16998</TH>
#   <TH>BnF 354</TH>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000"> Et il chevauche</TD>
#   <TD bgcolor="FF0000">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FF00">tant</TD>
#   <TD bgcolor="00FF00">tant</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">qu'il</TD>
#   <TD bgcolor="FF0000">qui</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FF00">vint a l'issue de la
# forest, si</TD>
#   <TD bgcolor="00FF00">vint a l'issue de la
# forest, si</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">vit</TD>
#   <TD bgcolor="FF0000">vint</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FF00">devant lui une
# maison de religion</TD>
#   <TD bgcolor="00FF00">devant lui une
# maison de religion</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">. Il</TD>
#   <TD bgcolor="FF0000">et il</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FF00">torne cele part por
# herbergier et quant
# il vint a la porte
# si</TD>
#   <TD bgcolor="00FF00">torne cele part por
# herbergier et quant
# il vint a la porte
# si</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">trouve</TD>
#   <TD bgcolor="FF0000">troeve</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FF00">IIII des freres qui
# avoient chante</TD>
#   <TD bgcolor="00FF00">IIII des freres qui
# avoient chante</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">complie que</TD>
#   <TD bgcolor="FF0000">conplie</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FF00">estoient venu au</TD>
#   <TD bgcolor="00FF00">estoient venu au</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">serein</TD>
#   <TD bgcolor="FF0000">serain</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FF00">. Si</TD>
#   <TD bgcolor="00FF00">. Si</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">ssaillent</TD>
#   <TD bgcolor="FF0000">saillent</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FF00">encontre lui</TD>
#   <TD bgcolor="00FF00">encontre lui</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">por li</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FF00">descendre et dient</TD>
#   <TD bgcolor="00FF00">descendre et dient</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">que</TD>
#   <TD bgcolor="FF0000">qui</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FF00">bien soit il venus.</TD>
#   <TD bgcolor="00FF00">bien soit il venus.</TD>
#  </TR>
# </TABLE>

# %%
collation = Collation()
witness_16998 = open( "paragrafo-1-16998.txt", encoding='utf-8' ).read()
witness_354 = open( "paragrafo-1-354.txt", encoding='utf-8' ).read()
collation.add_plain_witness( "BnF 16998", witness_16998 )
collation.add_plain_witness( "BnF 354", witness_354 )
alignment_table = collate(collation, near_match=True, layout='vertical', output='html2')
# Out:
#  tant 0.0
#  qui 0.0
# Et tant 0.3333333333333333
#  vint 0.0
# Et qui 0.0
# il tant 0.0
#  a 0.0
# Et vint 0.3333333333333333
# il qui 0.4
# chevauche tant 0.15384615384615385
#  l 0.0
# Et a 0.0
# il vint 0.3333333333333333
# chevauche qui 0.16666666666666666
#  ' 0.0
# Et l 0.0
# il a 0.0
# chevauche vint 0.15384615384615385
#  issue 0.0
# Et ' 0.0
# il l 0.6666666666666666
# chevauche a 0.2
# qu qui 0.8
#  de 0.0
# Et issue 0.0
#  la 0.0
# Et de 0.0
# chevauche ' 0.0
# ' vint 0.0
#  forest 0.0
# Et la 0.0
# chevauche issue 0.2857142857142857
# tant ' 0.0
# ' a 0.0
# il vint 0.3333333333333333
#  , 0.0
# Et forest 0.25
# chevauche de 0.18181818181818182
# tant issue 0.0
# ' l 0.0
# il a 0.0
#  si 0.0
# Et , 0.0
# chevauche la 0.18181818181818182
# tant de 0.0
# ' ' 1.0
# il l 0.6666666666666666
#  vint 0.0
# Et si 0.0
# chevauche forest 0.13333333333333333
# tant la 0.3333333333333333
#  devant 0.0
# Et vint 0.3333333333333333
# chevauche , 0.0
# tant forest 0.2
# il issue 0.2857142857142857
#  lui 0.0
# Et devant 0.25
# chevauche si 0.0
# tant , 0.0
# il de 0.0
#  une 0.0
# Et lui 0.0
# chevauche vint 0.15384615384615385
# tant si 0.0
# il la 0.5
#  maison 0.0
# Et une 0.0
# chevauche devant 0.4
# tant vint 0.5
# il forest 0.0
#  de 0.0
# Et maison 0.0
# chevauche lui 0.16666666666666666
# tant devant 0.6
# il , 0.0
#  religion 0.0
# Et de 0.0
# chevauche une 0.3333333333333333
# tant lui 0.0
# il si 0.5
#  et 0.0
# Et religion 0.0
# chevauche maison 0.13333333333333333
# tant une 0.2857142857142857
# il vint 0.3333333333333333
#  il 0.0
# Et et 0.5
# chevauche de 0.18181818181818182
# tant maison 0.4
# il devant 0.0
#  torne 0.0
# Et il 0.0
# chevauche religion 0.11764705882352941
# tant de 0.0
# il lui 0.4
#  cele 0.0
# Et torne 0.2857142857142857
# chevauche et 0.18181818181818182
# tant religion 0.16666666666666666
# il une 0.0
#  part 0.0
# Et cele 0.0
# chevauche il 0.0
# tant et 0.3333333333333333
# il maison 0.25
#  por 0.0
# Et part 0.3333333333333333
# chevauche torne 0.14285714285714285
# tant il 0.0
# il de 0.0
#  herbergier 0.0
# Et por 0.0
# chevauche cele 0.46153846153846156
# tant torne 0.4444444444444444
# il religion 0.2
#  et 0.0
# Et herbergier 0.0
# chevauche part 0.15384615384615385
# tant cele 0.0
# il et 0.0
#  quant 0.0
# Et et 0.5
# chevauche por 0.0
# tant part 0.5
# forest vint 0.2
#  il 0.0
# Et quant 0.2857142857142857
# chevauche herbergier 0.3157894736842105
# tant por 0.0
# forest devant 0.3333333333333333
#  vint 0.0
# Et il 0.0
# chevauche et 0.18181818181818182
# tant herbergier 0.0
# vint torne 0.2222222222222222
# forest lui 0.0
#  a 0.0
# Et vint 0.3333333333333333
# chevauche quant 0.14285714285714285
# tant et 0.3333333333333333
# vint cele 0.0
# forest une 0.2222222222222222
# vit vint 0.8571428571428571
#  la 0.0
# Et a 0.0
# chevauche il 0.0
# tant quant 0.6666666666666666
# vint part 0.25
# forest maison 0.16666666666666666
#  porte 0.0
# Et la 0.0
# chevauche vint 0.15384615384615385
# vint por 0.0
# forest de 0.25
#  si 0.0
# Et porte 0.2857142857142857
# chevauche a 0.2
# qu il 0.0
# vint herbergier 0.14285714285714285
# forest religion 0.2857142857142857
#  troeve 0.0
# Et si 0.0
# chevauche la 0.18181818181818182
# qu vint 0.0
# vint et 0.3333333333333333
# forest et 0.5
#  IIII 0.0
# Et troeve 0.25
# chevauche porte 0.14285714285714285
# qu a 0.0
# vint quant 0.4444444444444444
# forest il 0.0
#  des 0.0
# Et IIII 0.0
# chevauche si 0.0
# qu la 0.0
# vint il 0.3333333333333333
# forest torne 0.5454545454545454
#  freres 0.0
# Et des 0.0
# chevauche troeve 0.4
# qu porte 0.0
# vint vint 1.0
# forest cele 0.2
#  qui 0.0
# Et freres 0.0
# chevauche IIII 0.0
# qu si 0.0
# forest part 0.4
#  avoient 0.0
# Et qui 0.0
# chevauche des 0.16666666666666666
# qu troeve 0.0
# a a 1.0
# forest por 0.4444444444444444
#  chante 0.0
# Et avoient 0.2222222222222222
# chevauche freres 0.26666666666666666
# qu IIII 0.0
# forest herbergier 0.25
#  conplie 0.0
# Et chante 0.25
# chevauche qui 0.16666666666666666
# qu des 0.0
# forest et 0.5
#  estoient 0.0
# Et conplie 0.0
# chevauche avoient 0.25
# qu freres 0.0
# forest quant 0.18181818181818182
#  venu 0.0
# Et estoient 0.2
# chevauche chante 0.5333333333333333
# qu qui 0.8
# l si 0.0
# forest il 0.0
#  au 0.0
# Et venu 0.0
# chevauche conplie 0.25
# l troeve 0.0
# forest vint 0.2
# . et 0.0
#  serain 0.0
# Et au 0.0
# chevauche estoient 0.23529411764705882
# ' avoient 0.0
# l IIII 0.0
# forest a 0.0
# . il 0.0
# Il et 0.0
#  . 0.0
# Et serain 0.0
# chevauche venu 0.3076923076923077
# ' chante 0.0
# l des 0.0
# forest la 0.0
# . torne 0.0
# Il il 0.5
# torne et 0.2857142857142857
#  Si 0.0
# Et . 0.0
# chevauche au 0.36363636363636365
# ' conplie 0.0
# l freres 0.0
# forest porte 0.5454545454545454
# . cele 0.0
# Il torne 0.0
# torne il 0.0
# cele et 0.3333333333333333
#  saillent 0.0
# Et Si 0.0
# chevauche serain 0.26666666666666666
# ' estoient 0.0
# l qui 0.0
# forest si 0.25
# . part 0.0
# Il cele 0.3333333333333333
# cele il 0.3333333333333333
# part et 0.3333333333333333
#  encontre 0.0
# Et saillent 0.2
# chevauche . 0.0
# ' venu 0.0
# l avoient 0.0
# forest troeve 0.3333333333333333
# . por 0.0
# Il part 0.0
# part il 0.0
# por et 0.0
#  lui 0.0
# Et encontre 0.2
# chevauche Si 0.0
# ' au 0.0
# l chante 0.0
# forest IIII 0.0
# . herbergier 0.0
# Il por 0.0
# por il 0.0
# herbergier et 0.16666666666666666
#  por 0.0
# Et lui 0.0
# chevauche saillent 0.23529411764705882
# ' serain 0.0
# l conplie 0.25
# forest des 0.4444444444444444
# . et 0.0
# Il herbergier 0.0
# herbergier il 0.16666666666666666
# et et 1.0
#  li 0.0
# Et por 0.0
# chevauche encontre 0.35294117647058826
# ' . 0.0
# l estoient 0.0
# forest freres 0.6666666666666666
# . quant 0.0
# Il et 0.0
#  descendre 0.0
# Et li 0.0
# chevauche lui 0.16666666666666666
# ' Si 0.0
# l venu 0.0
# . il 0.0
# Il quant 0.0
# quant il 0.0
#  et 0.0
# Et descendre 0.0
# chevauche por 0.0
# ' saillent 0.0
# l au 0.0
# , qui 0.0
# . vint 0.0
# Il il 0.5
# il il 1.0
#  dient 0.0
# Et et 0.5
# chevauche li 0.0
# ' encontre 0.0
# l serain 0.0
# , avoient 0.0
# . a 0.0
# Il vint 0.0
#  qui 0.0
# Et dient 0.2857142857142857
# chevauche descendre 0.3333333333333333
# ' lui 0.0
# l . 0.0
# , chante 0.0
# . la 0.0
# Il a 0.0
#  bien 0.0
# Et qui 0.0
# chevauche et 0.18181818181818182
# ' por 0.0
# l Si 0.0
# , conplie 0.0
# . porte 0.0
# Il la 0.5
#  soit 0.0
# Et bien 0.0
# chevauche dient 0.14285714285714285
# ' li 0.0
# l saillent 0.2222222222222222
# , estoient 0.0
# . si 0.0
# Il porte 0.0
#  il 0.0
# Et soit 0.3333333333333333
# chevauche qui 0.16666666666666666
# ' descendre 0.0
# l encontre 0.0
# , venu 0.0
# . troeve 0.0
# Il si 0.0
#  venus 0.0
# Et il 0.0
# chevauche bien 0.15384615384615385
# ' et 0.0
# l lui 0.5
# , au 0.0
# . IIII 0.0
# Il troeve 0.0
#  . 0.0
# Et venus 0.0
# chevauche soit 0.0
# ' dient 0.0
# l por 0.0
# , serain 0.0
# . des 0.0
# Il IIII 0.3333333333333333
# Et . 0.0
# chevauche il 0.0
# ' qui 0.0
# l li 0.6666666666666666
# , . 0.0
# . freres 0.0
# Il des 0.0
# chevauche venus 0.2857142857142857
# ' bien 0.0
# , Si 0.0
# . qui 0.0
# Il freres 0.0
# chevauche . 0.0
# ' soit 0.0
# , saillent 0.0
# . avoient 0.0
# Il qui 0.0
# ' il 0.0
# , encontre 0.0
# . chante 0.0
# Il avoient 0.0
# ' venus 0.0
# , lui 0.0
# . conplie 0.0
# Il chante 0.0
# trouve et 0.25
# ' . 0.0
# , por 0.0
# . estoient 0.0
# Il conplie 0.2222222222222222
# IIII et 0.0
# , li 0.0
# . venu 0.0
# Il estoient 0.0
# trouve il 0.0
# des et 0.4
# , descendre 0.0
# . au 0.0
# Il venu 0.0
# IIII il 0.0
# freres et 0.25
# , et 0.0
# . serain 0.0
# Il au 0.0
# des il 0.0
# qui et 0.0
# , dient 0.0
# . . 1.0
# Il serain 0.0
# freres il 0.0
# avoient et 0.4444444444444444
# , qui 0.0
# qui il 0.4
# chante et 0.25
# , bien 0.0
# Il Si 0.0
# avoient il 0.2222222222222222
# complie et 0.2222222222222222
# , soit 0.0
# Il saillent 0.2
# torne Si 0.0
# trouve troeve 0.8333333333333334
# chante il 0.0
# que et 0.4
# , il 0.0
# Il encontre 0.0
# torne saillent 0.15384615384615385
# complie il 0.2222222222222222
# estoient et 0.4
# , venus 0.0
# Il lui 0.4
# torne encontre 0.46153846153846156
# que il 0.0
# venu et 0.3333333333333333
# , . 0.0
# Il por 0.0
# torne lui 0.0
# estoient il 0.2
# au et 0.0
# Il li 0.5
# torne por 0.5
# venu il 0.0
# serein et 0.25
# Il descendre 0.0
# torne li 0.0
# au il 0.0
# . et 0.0
# Il et 0.0
# torne descendre 0.2857142857142857
# serein il 0.25
# Si et 0.0
# Il dient 0.0
# torne et 0.2857142857142857
# . il 0.0
# ssaillent et 0.36363636363636365
# Il qui 0.0
# torne dient 0.2
# Si il 0.5
# encontre et 0.4
# Il bien 0.0
# torne qui 0.0
# ssaillent il 0.36363636363636365
# lui et 0.0
# Il soit 0.0
# torne bien 0.2222222222222222
# encontre il 0.0
# descendre et 0.18181818181818182
# Il il 0.5
# torne soit 0.2222222222222222
# lui il 0.4
# et et 1.0
# Il venus 0.0
# torne il 0.0
# descendre il 0.0
# Il . 0.0
# torne venus 0.2
# et il 0.0
# dient quant 0.4
# torne . 0.0
# complie conplie 0.8571428571428571
# dient il 0.2857142857142857
# que quant 0.5
# que il 0.0
# bien quant 0.2222222222222222
# que estoient 0.18181818181818182
# bien il 0.3333333333333333
# soit quant 0.2222222222222222
# que venu 0.2857142857142857
# soit il 0.3333333333333333
# il quant 0.0
# que au 0.4
# il il 1.0
# venus quant 0.2
# que serain 0.2222222222222222
# . quant 0.0
# que . 0.0
# que Si 0.0
# que saillent 0.18181818181818182
# que encontre 0.18181818181818182
# serein serain 0.8333333333333334
# que lui 0.3333333333333333
# que por 0.0
# que li 0.0
# que descendre 0.16666666666666666
# que et 0.4
# que dient 0.25
# ssaillent saillent 0.9411764705882353
# que qui 0.6666666666666666
# estoient bien 0.5
# estoient soit 0.6666666666666666
# descendre por 0.16666666666666666
# descendre li 0.0
# et por 0.0
# venu . 0.0
# et li 0.0
# dient por 0.0
# dient li 0.2857142857142857
# que por 0.0
# que li 0.0
# bien por 0.0
# bien li 0.3333333333333333
# soit por 0.2857142857142857
# soit li 0.3333333333333333
# il por 0.0
# il li 0.5
# venus por 0.0
# que qui 0.6666666666666666
# venus li 0.0
# . por 0.0
# . li 0.0
# <TABLE border="1" cellpadding="4" style="border: 1px solid #000000; border-collapse: collapse;">
#  <TR>
#   <TH>BnF 16998</TH>
#   <TH>BnF 354</TH>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000"> Et il chevauche</TD>
#   <TD bgcolor="FF0000">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FF00">tant</TD>
#   <TD bgcolor="00FF00">tant</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">qu'il</TD>
#   <TD bgcolor="FF0000">qui</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FF00">vint a l'issue de la
# forest, si</TD>
#   <TD bgcolor="00FF00">vint a l'issue de la
# forest, si</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">vit</TD>
#   <TD bgcolor="FF0000">vint</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FF00">devant lui une
# maison de religion</TD>
#   <TD bgcolor="00FF00">devant lui une
# maison de religion</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">. Il</TD>
#   <TD bgcolor="FF0000">et il</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FF00">torne cele part por
# herbergier et quant
# il vint a la porte
# si</TD>
#   <TD bgcolor="00FF00">torne cele part por
# herbergier et quant
# il vint a la porte
# si</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">trouve</TD>
#   <TD bgcolor="FF0000">troeve</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FF00">IIII des freres qui
# avoient chante</TD>
#   <TD bgcolor="00FF00">IIII des freres qui
# avoient chante</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">complie que</TD>
#   <TD bgcolor="FF0000">conplie</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FF00">estoient venu au</TD>
#   <TD bgcolor="00FF00">estoient venu au</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">serein</TD>
#   <TD bgcolor="FF0000">serain</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FF00">. Si</TD>
#   <TD bgcolor="00FF00">. Si</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">ssaillent</TD>
#   <TD bgcolor="FF0000">saillent</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FF00">encontre lui</TD>
#   <TD bgcolor="00FF00">encontre lui</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">por li</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FF00">descendre et dient</TD>
#   <TD bgcolor="00FF00">descendre et dient</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">que</TD>
#   <TD bgcolor="FF0000">qui</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FF00">bien soit il venus.</TD>
#   <TD bgcolor="00FF00">bien soit il venus.</TD>
#  </TR>
# </TABLE>

# %%
collation = Collation()
witness_16998 = open( "paragrafo-1-16998.txt", encoding='utf-8' ).read()
witness_354 = open( "paragrafo-1-354.txt", encoding='utf-8' ).read()
collation.add_plain_witness( "BnF 16998", witness_16998 )
collation.add_plain_witness( "BnF 354", witness_354 )
graph = collate( collation, output="svg", segmentation=True )
